# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\piani\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\piani\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\piani\anaconda3\lib\site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in c:\users\piani\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\piani\anaconda3\lib\site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\piani\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\piani\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\piani\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\piani\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\piani\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import tweepy, codecs


consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# # kod ile tweet atmak

# %%
api.update_status("Hello from Python for Udemy Data Science and Machine Learning Course")
# Out:
# Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:11:30 +0000 2020', 'id': 1278345493542776832, 'id_str': '1278345493542776832', 'text': 'Hello from Python for Udemy Data Science and Machine Learning Course', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cfktekstil.com" rel="nofollow">cfktekstil</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 537344047, 'id_str': '537344047', 'name': 'Sürrealizmm', 'screen_name': 'surrealizmb', 'location': '', 'description': 'Öyle olmayaydi Böyle Olacağı yoktu', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 317, 'friends_count': 1240, 'listed_count': 0, 'created_at': 'Mon Mar 26 16:16:07 +0000 2012', 'favourites_count': 253, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 412, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/537344047/1403532523', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 1, 15, 11, 30), id=1278345493542776832, id_str='1278345493542776832', text='Hello from Python for Udemy Data Science and Machine Learning Course', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='cfktekstil', source_url='https://cfktekstil.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'id': 537344047, 'id_str': '537344047', 'name': 'Sürrealizmm', 'screen_name': 'surrealizmb', 'location': '', 'description': 'Öyle olmayaydi Böyle Olacağı yoktu', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 317, 'friends_count': 1240, 'listed_count': 0, 'created_at': 'Mon Mar 26 16:16:07 +0000 2012', 'favourites_count': 253, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 412, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/537344047/1403532523', 'profile_link_color': '1DA1F2', 'profile_side ...

# %% [markdown]
# # Twitter'dan Veri Çekimi

# %%
mvk = api.me()

# %%
mvk.screen_name
# Out:
# 'surrealizmb'

# %%
mvk.followers_count
# Out:
# 317

# %%
mvk.friends
# Out:
# <bound method User.friends of User(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'id': 537344047, 'id_str': '537344047', 'name': 'Sürrealizmm', 'screen_name': 'surrealizmb', 'location': '', 'profile_location': None, 'description': 'Öyle olmayaydi Böyle Olacağı yoktu', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 317, 'friends_count': 1240, 'listed_count': 0, 'created_at': 'Mon Mar 26 16:16:07 +0000 2012', 'favourites_count': 253, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 412, 'lang': None, 'status': {'created_at': 'Wed Jul 01 15:11:30 +0000 2020', 'id': 1278345493542776832, 'id_str': '1278345493542776832', 'text': 'Hello from Python for Udemy Data Science and Machine Learning Course', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cfktekstil.com" rel="nofollow">cfktekstil</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/481076827021381633/JPfZddB0_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/537344047/1403532523', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'suspended': False, 'needs_phone_verification': False}, id=537344047, id_str='537344047', name='Sürrealizmm', screen_name='surrealizmb', location='', profile_location=None, description='Öyle olmayaydi Böyle Olacağı yoktu', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=317, friends_count=1240, listed_count=0, created_at=datetime.datetime(2012, 3, 26, 16, 16, 7), favourites_count=253, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=412, lang=None, status=Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:11:30 +0000 2020', 'id': 1278345493542776832, 'id_str': '1278345493542776832', 'text': 'Hello from Python for Udemy Data Science and Machine Learning Course', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://cfktekstil.com" rel="nofollow">cfktekstil</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 1, 15, 11, 30), id=1278345493542776832, id_str='1278345493542776832', text='Hello from Python for Udemy Data Science and Machine Learning Course', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='cfktekstil', source_url='https://cfktekstil.com', in_reply_to_stat ...

# %%
for friend in mvk.friends(count = 3):
    print(friend.screen_name)
# Out:
# mervenoyann
# Khontkar
# latichannel

# %%
dir(mvk)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'needs_phone_verification',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_location',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'suspended',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %% [markdown]
#  # kullanıcı temel bilgileri

# %%
user = api.get_user(id = "Khontkar")

# %%
dir(user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_location',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %%
user.screen_name
# Out:
# 'Khontkar'

# %%
user.followers_count
# Out:
# 120649

# %%
# ?user
# Out:
# Type:        User
# String form: User(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'id': 36413418, 'id_str': '364134 <...> ge=False, following=True, follow_request_sent=False, notifications=False, translator_type='none')
# File:        c:\users\piani\anaconda3\lib\site-packages\tweepy\models.py
# Docstring:   <no docstring>

# %%
dir(user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_location',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %%
user.profile_image_url
# Out:
# 'http://pbs.twimg.com/profile_images/1275814830675542016/GL0LLXln_normal.jpg'

# %% [markdown]
# # hometimeline

# %%
public_tweets = api.home_timeline(count = 10)

# %%
public_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:23:19 +0000 2020', 'id': 1278348467908292611, 'id_str': '1278348467908292611', 'text': "Sosyal medya üzerinden Hazine ve Maliye Bakanı Berat Albayrak ve ailesine hakaret eden 5 şüpheli İstanbul'da gözalt… https://t.co/QOJpsO2LnW", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QOJpsO2LnW', 'expanded_url': 'https://twitter.com/i/web/status/1278348467908292611', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 218078497, 'id_str': '218078497', 'name': 'Sözcü', 'screen_name': 'gazetesozcu', 'location': 'İstanbul', 'description': "Sözcü Gazetesi'nin resmi Twitter hesabıdır.", 'url': 'https://t.co/iKm6hfPSra', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKm6hfPSra', 'expanded_url': 'https://www.instagram.com/sozcucomtr/', 'display_url': 'instagram.com/sozcucomtr/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2472383, 'friends_count': 29, 'listed_count': 2319, 'created_at': 'Sun Nov 21 10:42:48 +0000 2010', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 684861, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/598482594401882113/USVlP7kX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/598482594401882113/USVlP7kX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/218078497/1583407953', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'tr'}, created_at=datetime.datetime(2020, 7, 1, 15, 23, 19), id=1278348467908292611, id_str='1278348467908292611', text="Sosyal medya üzerinden Hazine ve Maliye Bakanı Berat Albayrak ve ailesine hakaret eden 5 şüpheli İstanbul'da gözalt… https://t.co/QOJpsO2LnW", truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QOJpsO2LnW', 'expanded_url': 'https://twitter.com/i/web/status/1278348467908292611', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'id': 218078497, 'id_str': '218078497', 'name': 'Sözcü', 'screen_name': 'gazetesozcu', 'location': 'İstanbul', 'description': "Sözcü Gazetesi'nin resmi Twitter hesabıdır.", 'url': 'https://t.co/iKm6hfPSra', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKm6hfPSra', 'expanded_url': 'https://www.instagram.com/sozcucomtr/', 'display_url': 'instagram.com/sozcucomtr/',  ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:23:13 +0000 2020', 'id': 1278348439353536512, 'id_str': '1278348439353536512', 'text': 'RT @sehinsahakahs: #SosyalMedyamaDOKUNMA', 'truncated': False, 'entities': {'hashtags': [{'text': 'SosyalMedyamaDOKUNMA', 'indices': [19, 40]}], 'symbols': [], 'user_mentions': [{'screen_name': 'sehinsahakahs', 'name': 'ŞEHİNŞAH', 'id': 103610520, 'id_str': '103610520', 'indices': [3, 17]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 
}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 343246972, 'id_str': '343246972', 'name': 'füsun demirel', 'screen_name': 'fusundemirel', 'location': '', 'description': 'oyuncu.çevirmen (attrice,traduttrice\nInstagram: fusundemirel_official', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 61432, 'friends_count': 996, 'listed_count': 63, 'created_at': 'Wed Jul 27 08:18:31 +0000 2011', 'favourites_count': 9534, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 18597, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1123279688489668610/Nu1sQ1ta_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1123279688489668610/Nu1sQ1ta_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/343246972/1510863718', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Jul 01 12:11:31 +0000 2020', 'id': 1278300196552744960, 'id_str': '1278300196552744960', 'text': 'Ama bana #beddua ettirmeyi nasıl başardın sen be kadın. https://t.co/1VauEdqnff', 'truncated': False, 'entities': {'hashtags': [{'text': 'beddua', 'indices': [9, 16]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/1VauEdqnff', 'expanded_url': 'https://twitter.com/serdar213441/status/1278286783646699520', 'display_url': 'twitter.com/serdar213441/s…', 'indices': [56, 79]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 213642691, 'id_str': '213642691', 'name': 'Muzaffer güsar', 'screen_name': 'muzoresmihesabi', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 7849, 'friends_count': 70, 'listed_count': 6, 'created_at': 'Tue Nov 09 12:43:36 +0000 2010', 'favourites_count': 2638, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2759, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'DBE9ED', 'profile_backg ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:22:11 +0000 2020', 'id': 1278348182095888384, 'id_str': '1278348182095888384', 'text': 'Gençlik ile siyasilerin\n “mavra/goy goy ” zamanlamaları uymuyor.\n“Elimdeki alınacak mı acaba”  derken \n“şaka” mı dinler.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 80931720, 'id_str': '80931720', 'name': 'Ceyhun Yılmaz', 'screen_name': 'ceyhunyilmaz', 'location': 'Istanbul, TR', 'description': 'iknatör / sandırıcı', 'url': 'https://t.co/NwnPhpD4iB', 'entities': {'url': {'urls': [{'url': 'https://t.co/NwnPhpD4iB', 'expanded_url': 'http://ceyhunyilmaz.com', 'display_url': 'ceyhunyilmaz.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1353013, 'friends_count': 676, 'listed_count': 1493, 'created_at': 'Thu Oct 08 20:10:50 +0000 2009', 'favourites_count': 1673, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 89944, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '3E3D3F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/682175100876140544/t9ylf7cR_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/682175100876140544/t9ylf7cR_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80931720/1463524598', 'profile_link_color': 'C60629', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '9C9A9B', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 4, 'favorited': False, 'retweeted': False, 'lang': 'tr'}, created_at=datetime.datetime(2020, 7, 1, 15, 22, 11), id=1278348182095888384, id_str='1278348182095888384', text='Gençlik ile siyasilerin\n “mavra/goy goy ” zamanlamaları uymuyor.\n“Elimdeki alınacak mı acaba”  derken \n“şaka” mı dinler.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'id': 80931720, 'id_str': '80931720', 'name': 'Ceyhun Yılmaz', 'screen_name': 'ceyhunyilmaz', 'location': 'Istanbul, TR', 'description': 'iknatör / sandırıcı', 'url': 'https://t.co/NwnPhpD4iB', 'entities': {'url': {'urls': [{'url': 'https://t.co/NwnPhpD4iB', 'expanded_url': 'http://ceyhunyilmaz.com', 'display_url': 'ceyhunyilmaz.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1353013, 'friends_count': 676, 'listed_count': 1493, 'created_at': 'Thu Oct 08 20:10:50 +0000 2009', 'favourites_count': 1673, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count':
}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1291875558, 'id_str': '1291875558', 'name': 'BEŞİKTAŞ Var! #BırakmamSeni', 'screen_name': 'NoirBlancAsk', 'location': 'Burda kimse yokken biz vardık ', 'description': "DM odalarına eklemeyin!\nhiç bir guruplaşmaya katılmıyorum!\nSana gelmediğim gün öldüğüm gündür benim @Besiktas😍🦅\nM.KEMAL'İN İZİNDE! \nProfosyonel Kick Boksçu👊", 'url': 'https://t.co/owYjsPzJVj', 'entities': {'url': {'urls': [{'url': 'https://t.co/owYjsPzJVj', 'expanded_url': 'http://www.instagram.com/NoirBlancAsk', 'display_url': 'instagram.com/NoirBlancAsk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 48781, 'friends_count': 6001, 'listed_count': 32, 'created_at': 'Sat Mar 23 16:32:58 +0000 2013', 'favourites_count': 75800, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 150113, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1271465046019801088/4bZJHymt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271465046019801088/4bZJHymt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1291875558/1591174209', 'profile_link_color': 'F5ABB5', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Jul 01 13:09:35 +0000 2020', 'id': 1278314811248566272, 'id_str': '1278314811248566272', 'text': '@NoirBlancAsk Zehir zıkkım olsun', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'NoirBlancAsk', 'name': 'BEŞİKTAŞ Var! #BırakmamSeni', 'id': 1291875558, 'id_str': '1291875558', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1278273727734722566, 'in_reply_to_status_id_str': '1278273727734722566', 'in_reply_to_user_id': 1291875558, 'in_reply_to_user_id_str': '1291875558', 'in_reply_to_screen_name': 'NoirBlancAsk', 'user': {'id': 926149738159894529, 'id_str': '926149738159894529', 'name': 'Zaralı', 'screen_name': 'Zaral28248124', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 906, 'friends_count': 1676, 'listed_count': 0, 'created_at': 'Thu Nov 02 18:11:19 +0000 2017', 'favourites_count': 52643, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 82 ...

# %%
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Sosyal medya üzerinden Hazine ve Maliye Bakanı Berat Albayrak ve ailesine hakaret eden 5 şüpheli İstanbul'da gözalt… https://t.co/QOJpsO2LnW
# RT @sehinsahakahs: #SosyalMedyamaDOKUNMA
# evli ve sevgilisi olan erkek gerginligi var bugun ustumde
# RT @muzoresmihesabi: Ama bana #beddua ettirmeyi nasıl başardın sen be kadın. https://t.co/1VauEdqnff
# Gençlik ile siyasilerin
#  “mavra/goy goy ” zamanlamaları uymuyor.
# “Elimdeki alınacak mı acaba”  derken
# “şaka” mı dinler.
# #SONDAKİKA | BM Güvenlik Konseyi'nden flaş karar! Küresel ateşkes kararı kabul edildi https://t.co/Dd2dGLVPy5 https://t.co/LIEqvc1W8R
# 📌 Mehmet Demirkol: "Bundan sonra böyle mi uygulanacak? Başkan sahaya girdiği zaman 15 gün mü bundan sonra?" #beINMANŞET
# RT @bayanyani: Olmayınca olmayor
# #SosyalMedyamaDokunma https://t.co/QDCMANa7uL
# Fransa'dan AB'ye Türkiye çağrısı! https://t.co/WdVXeZUvbB
# RT @Zaral28248124: @NoirBlancAsk Zehir zıkkım olsun

# %% [markdown]
# # user timeline

# %%
name = "Khontkar"
tweet_count = 10

user_timetime = api.user_timeline(id = name, count = tweet_count)

for i in user_timetime:
    print(i.text)
# Out:
# Tripster Freestyle 💯 https://t.co/WeloMeQc1M @BixiBlake @stabdasaber @RedKeysMusic #TRAPKINGZ 💸⛓
# GANG GANG https://t.co/BrwSF0k1PE
# Ta Kendisiyle Bölüm #4 - Dinazorlarla İnternetten Sonra Türkiye'de Rap (... https://t.co/QSR3M08RaH @MetthMan… https://t.co/FiKSrPCB3d
# @miksenginari mixlerin neden kötü olduğu belli oldu
# #METFLIXDELUXE de @MetthMan &amp; @simulasyxn un böyle bi parçada bana yer verdikleri için teşekkürler 💸🎹💯⛓🐐
# 🙏🏻 https://t.co/Bh7zJuU4v2
# Hatta birazda daha ileri gidip @gucci1017 yi burda da darlayalım herkes postun altına “SIGN HIM 🥶” yazıp beni etiketlesin 💯🙏🏻💸⛓🐐 #OVERSEAS
# IG de paylaştım buraya da atayım postu. Dinleyicilerimden minik bir ricam. Herkes IG de postun altına “🥶” atıp beni… https://t.co/BwEjkFyp8R
# Sınava girecek tüm arkadaşlara da ayrıca başarılar. Dediğim gibi kendinize İNANIN! #ModernThug 💯
# Başarıdan korkmayın. Kimse size inanmayabilir. Önce kendinize inanın. Savaşın. Mücadele edin. #ModernThug 💯

# %% [markdown]
# # retweet edilen tweetler

# %%
retweets = api.retweets_of_me(count = 3)
for retweet in retweets:
    print(retweet.text)
# Out:
# Hello from Python for Udemy Data Science and Machine Learning Course
# Sanırım BELKİ BAŞKA ZAMAN. Üzgünüm baykuş 🦉 https://t.co/RPw1ms0K5N
# @Hayki34 Bence sende deme. Damla abla nerde napiyor. Nasıl ayrılmıştınz. Aranıza despo mu girsin... Eskilere girerk… https://t.co/VV8Wp5QukC

# %% [markdown]
# # hashtag

# %%
results = api.search(q = "#pazartesi", 
                     lang = "tr", 
                     result_type = "recent", 
                     count = 100)

# %%
results
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:23:45 +0000 2020', 'id': 1278348575794237440, 'id_str': '1278348575794237440', 'text': 'RT @nurana571: Allah rahmet eylesin inşallah🤲 çok beğendim 👍👍📌 #anlatamam #kayahan #pazartesi #facebook_vs_twitter ⚖️https://t.co/6IN6zM099w', 'truncated': False, 'entities': {'hashtags': [{'text': 'anlatamam', 'indices': [63, 73]}, {'text': 'kayahan', 'indices': [74, 82]}, {'text': 'pazartesi', 'indices': [83, 93]}, {'text': 'facebook_vs_twitter', 'indices': [94, 114]}], 'symbols': [], 'user_mentions': [{'screen_name': 'nurana571', 'name': 'nurana ¿ mı,🌴🌱🇹🇷', 'id': 2987129453, 'id_str': '2987129453', 'indices': [3, 13]}], 'urls': [{'url': 'https://t.co/6IN6zM099w', 'expanded_url': 'https://www.facebook.com/1865711923661988/posts/2789834301249741/?sfnsn=scwspmo&extid=uK4078RXwiYwA72k&d=n&vh=e', 'display_url': 'facebook.com/18657119236619…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2987129453, 'id_str': '2987129453', 'name': 'nurana ¿ mı,🌴🌱🇹🇷', 'screen_name': 'nurana571', 'location': 'İstanbul', 'description': 'ön yargılı olmaa🚮🛂👉EMPATİLİ👈 OL👍 \nO,da seni inceliyor~\nSütten ağzım yandı ise~\nMeselesi ölmüş kuşlara şiir okumakmış hemde güpegündüz~🙆\u200d♀️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 337, 'friends_count': 386, 'listed_count': 0, 'created_at': 'Tue Jan 20 11:12:13 +0000 2015', 'favourites_count': 2021, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3678, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1269649418355122177/CyvQl84b_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269649418355122177/CyvQl84b_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2987129453/1489823310', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 10:55:37 +0000 2020', 'id': 1277556319420112897, 'id_str': '1277556319420112897', 'text': 'Allah rahmet eylesin inşallah🤲 çok beğendim 👍👍📌 #anlatamam #kayahan #pazartesi #facebook_vs_twitter ⚖️https://t.co/6IN6zM099w', 'truncated': False, 'entities': {'hashtags': [{'text': 'anlatamam', 'indices': [48, 58]}, {'text': 'kayahan', 'indices': [59, 67]}, {'text': 'pazartesi', 'indices': [68, 78]}, {'text': 'facebook_vs_twitter', 'indices': [79, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/6IN6zM099w', 'expanded_url': 'https://www.facebook.com/1865711923661988/posts/2789834301249741/?sfnsn=scwspmo&extid=uK4078RXwiYwA72k&d=n&vh=e', 'display_url': 'facebook.com/18657119236619…', 'indices': [102, 125]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_ ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:22:58 +0000 2020', 'id': 1278348377860780033, 'id_str': '1278348377860780033', 'text': 'RT @sademofficial: insan diyorum,\n\nzamanla değişmiyor,  \n\nzorla değiştiriliyor________\n\n       G ü n a y d ı n   o   vakit \n\n#pazartesi htt…', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [125, 135]}], 'symbols': [], 'user_mentions': [{'screen_name': 'sademofficial', 'name': 'Sadem_____👠', 'id': 3166994921, 'id_str': '3166994921', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1252371583315959808, 'id_str': '1252371583315959808', 'name': 'Pınar GÜL', 'screen_name': 'gl75249889', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 40, 'friends_count': 34, 'listed_count': 1, 'created_at': 'Mon Apr 20 23:01:41 +0000 2020', 'favourites_count': 1792, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1801, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1252383831836876806/EZUPN4Rt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252383831836876806/EZUPN4Rt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1252371583315959808/1587848895', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 06:45:15 +0000 2020', 'id': 1277493314145660928, 'id_str': '1277493314145660928', 'text': 'insan diyorum,\n\nzamanla değişmiyor,  \n\nzorla değiştiriliyor________\n\n       G ü n a y d ı n   o   vakit \n\n#pazartesi https://t.co/1IjVs7sj6L', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [106, 116]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1277493312111480832, 'id_str': '1277493312111480832', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'url': 'https://t.co/1IjVs7sj6L', 'display_url': 'pic.twitter.com/1IjVs7sj6L', 'expanded_url': 'https://twitter.com/sademofficial/status/1277493314145660928/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 312, 'h': 340, 'resize': 'fit'}, 'medium': {'w': 312, 'h': 340, 'resize': 'fit'}, 'large': {'w': 312, 'h': 340, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1277493312111480832, 'id_str': '1277493312111480832', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'url': 'https://t.co/1IjVs7sj6L', 'display_url': 'pic.twitter.com/1IjVs7sj6L', 'expanded_url': 'https://twitter.com/sademofficial/status/1277493314145660928/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 312, 'h': 340, 'resize': 'fit'}, 'medium': {'w': 312 ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:20:31 +0000 2020', 'id': 1278347760052441088, 'id_str': '1278347760052441088', 'text': 'RT @mazidekalmiss: Selâmun Aleykűm Dostlar\nYüreğiyle konuşan\nİnsanlar olsun hayatınızda\nGüzel bakışlarıyla\nSıcak içten samimi\nBi içimlik so…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'mazidekalmiss', 'name': 'Rizelim.💕', 'id': 2300167634, 'id_str': '2300167634', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1173293435396263936, 'id_str': '1173293435396263936', 'name': '.', 'screen_name': 'H12Vesile', 'location': '', 'description': '🇹🇷  Her Yerde Edeb 🌹\n@vesilehosbas12', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1017, 'friends_count': 1349, 'listed_count': 0, 'created_at': 'Sun Sep 15 17:52:31 +0000 2019', 'favourites_count': 43739, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 13356, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1270142051213082626/Kk15aA_m_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270142051213082626/Kk15aA_m_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1173293435396263936/1593194283', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 01:41:50 +0000 2020', 'id': 1277416958758129666, 'id_str': '1277416958758129666', 'text': 'Selâmun Aleykűm Dostlar\nYüreğiyle konuşan\nİnsanlar olsun hayatınızda\nGüzel bakışlarıyla\nSıcak içten samimi\nBi içiml… https://t.co/mGk9IQcWnw', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/mGk9IQcWnw', 'expanded_url': 'https://twitter.com/i/web/status/1277416958758129666', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2300167634, 'id_str': '2300167634', 'name': 'Rizelim.💕', 'screen_name': 'mazidekalmiss', 'location': 'Türkiyetakipedenitakipederim', 'description': 'yazdıklarım beni bağlar kimseyle alakası yok siyasetle ilgilenmiyorum küfürlü konuşanlar takip etmesin her görüşe saygım var evli 6 /6/1966 erk.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 27753, 'friends_count': 23733, 'listed_count': 40, 'created_at': 'Sun Jan 19 18:57:26 +0000 2014', 'favourites_count': 295187, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 21269, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, ' ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:18:14 +0000 2020', 'id': 1278347187303460864, 'id_str': '1278347187303460864', 'text': 'RT @sademofficial: insan diyorum,\n\nzamanla değişmiyor,  \n\nzorla değiştiriliyor________\n\n       G ü n a y d ı n   o   vakit \n\n#pazartesi htt…', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [125, 135]}], 'symbols': [], 'user_mentions': [{'screen_name': 'sademofficial', 'name': 'Sadem_____👠', 'id': 3166994921, 'id_str': '3166994921', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1252369830147231744, 'id_str': '1252369830147231744', 'name': 'Pınar Gül', 'screen_name': 'PnarGl72384719', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 49, 'friends_count': 34, 'listed_count': 0, 'created_at': 'Mon Apr 20 22:55:09 +0000 2020', 'favourites_count': 1940, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1963, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1252370615190736900/C7OD_DfK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252370615190736900/C7OD_DfK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1252369830147231744/1587423506', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 06:45:15 +0000 2020', 'id': 1277493314145660928, 'id_str': '1277493314145660928', 'text': 'insan diyorum,\n\nzamanla değişmiyor,  \n\nzorla değiştiriliyor________\n\n       G ü n a y d ı n   o   vakit \n\n#pazartesi https://t.co/1IjVs7sj6L', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [106, 116]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1277493312111480832, 'id_str': '1277493312111480832', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'url': 'https://t.co/1IjVs7sj6L', 'display_url': 'pic.twitter.com/1IjVs7sj6L', 'expanded_url': 'https://twitter.com/sademofficial/status/1277493314145660928/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 312, 'h': 340, 'resize': 'fit'}, 'medium': {'w': 312, 'h': 340, 'resize': 'fit'}, 'large': {'w': 312, 'h': 340, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1277493312111480832, 'id_str': '1277493312111480832', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbqRZh9XkAA9hQF.jpg', 'url': 'https://t.co/1IjVs7sj6L', 'display_url': 'pic.twitter.com/1IjVs7sj6L', 'expanded_url': 'https://twitter.com/sademofficial/status/1277493314145660928/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 312, 'h': 340, 'resize': 'fit'}, 'medium': {'w': ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:17:15 +0000 2020', 'id': 1278346937520005120, 'id_str': '1278346937520005120', 'text': 'RT @AnkaraTakipte: HALK EKMEK yönetimi \nİtiraf etti. \n\n“20 yıldır ödemelerimizde aksama olmuyordu”\n\nMANSUR YAVAŞ yönetimi tıkır tıkır işley…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AnkaraTakipte', 'name': 'Ankara Takipte', 'id': 1088044802250338309, 'id_str': '1088044802250338309', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1128568443383554048, 'id_str': '1128568443383554048', 'name': 'Suatusta', 'screen_name': 'Suatust46627768', 'location': '', 'description': 'doner', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count':
 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10633, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1238061536121434113/2hzBbmfY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1238061536121434113/2hzBbmfY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1200168896105472002/1584012248', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 04:58:31 +0000 2020', 'id': 1277466454124834816, 'id_str': '1277466454124834816', 'text': 'Biraz da kendin için yaşayınca \ngüzelleşiyor hayat!\nBiraz durup soluklanınca dinleniyor \nyürek.\nGelmeyeni umursamad… https://t.co/2xhUOQ4jSb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2xhUOQ4jSb', 'expanded_url': 'https://twitter.com/i/web/status/1277466454124834816', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3903252978, 'id_str': '3903252978', 'name': '✿🅴🅲🅴🅼✿', 'screen_name': 'ecemli89', 'location': 'Deutschland 🇩🇪', 'description': 'Wahre Liebe hat kein Happy End,Wahre Liebe endet nicht . 💕 @ewigeliebe89 🧚\u200d♀️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 26930, 'friends_count': 3475, 'listed_count': 181, 'created_at': 'Thu Oct 15 13:55:00 +0000 2015', 'favourites_count': 359844, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4910, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translatio ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:06:17 +0000 2020', 'id': 1278344178104221696, 'id_str': '1278344178104221696', 'text': 'RT @furkanvakfi: Kurulduğu günden bu yana Öncü bir nesil yetiştirmek amacıyla hayırlı hizmetlerde bulunan vakfımızın kapısına 881 gündür ki…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'furkanvakfi', 'name': 'Furkan Vakfı', 'id': 68389175, 'id_str': '68389175', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 731776248108728320, 'id_str': '731776248108728320', 'name': 'Ahdevefa', 'screen_name': 'ahdevefa011', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 743, 'friends_count': 1273, 'listed_count': 0, 'created_at': 'Sun May 15 09:20:28 +0000 2016', 'favourites_count': 20091, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 21991, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1062412514745638912/YMLDQtCW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1062412514745638912/YMLDQtCW_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/731776248108728320/1492797691', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 12:40:26 +0000 2020', 'id': 1277582698601742336, 'id_str': '1277582698601742336', 'text': 'Kurulduğu günden bu yana Öncü bir nesil yetiştirmek amacıyla hayırlı hizmetlerde bulunan vakfımızın kapısına 881 gü… https://t.co/UMh64czYWq', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/UMh64czYWq', 'expanded_url': 'https://twitter.com/i/web/status/1277582698601742336', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 68389175, 'id_str': '68389175', 'name': 'Furkan Vakfı', 'screen_name': 'furkanvakfi', 'location': 'Türkiye', 'description': 'Biz Medeniyetimize Dönüyoruz..Furkan WhatsApp İletişim Hattı: +90 (535) 231 22 32 https://t.co/G78k3tIBrR', 'url': 'https://t.co/zUFSN0e6xf', 'entities': {'url': {'urls': [{'url': 'https://t.co/zUFSN0e6xf', 'expanded_url': 'https://furkanvakfi.org/', 'display_url': 'furkanvakfi.org', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/G78k3tIBrR', 'expanded_url': 'https://api.whatsapp.com/send?phone=905352312232&text=Selamun%20Aleyk%C3%BCm', 'display_url': 'api.whatsapp.com/send?phone=905…', 'indices': [82, 105]}]}}, 'protected': False, 'followers_count': 76751, 'friends_count': 4, 'listed_count': 83, 'created_at': 'Mon Aug 24 11:50 ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:06:14 +0000 2020', 'id': 1278344165328400384, 'id_str': '1278344165328400384', 'text': 'RT @SehzadeEbru: Tarih seni yetkiliydi ama etkisiz elemandı\n\nŞimdi de etkisiz  ama yetkili eleman gibi davranan bir HİÇ olarak yazacak...…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SehzadeEbru', 'name': '🇹🇷EBRU ŞEHZADE🇹🇷', 'id': 840937471827443714, 'id_str': '840937471827443714', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 846799952823177221, 'id_str': '846799952823177221', 'name': 'Deli Kurt 🇹🇷🤘🇹🇷RT', 'screen_name': 'isimsizdelirt', 'location': 'İstanbul, Türkiye', 'description': 'BJK⚪⚫Ana Hesap: @isimsizdeli44\nİstanbul Üniversitesi Medya ve İletişim Fakültesi Mezunu \nMUHSİN Başkan yolunda/DEVLETin yanında/REİSin Emrindeyiz..!', 'url': 'https://t.co/rVeIuyOEdw', 'entities': {'url': {'urls': [{'url': 'https://t.co/rVeIuyOEdw', 'expanded_url': 'http://instagram.com/isimsizdeli44', 'display_url': 'instagram.com/isimsizdeli44', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 4159, 'friends_count': 2588, 'listed_count': 1, 'created_at': 'Tue Mar 28 19:03:36 +0000 2017', 'favourites_count': 276195, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 295271, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1174306738063007744/rNVpbiiy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1174306738063007744/rNVpbiiy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/846799952823177221/1568193102', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 07:04:34 +0000 2020', 'id': 1277498176774307841, 'id_str': '1277498176774307841', 'text': 'Tarih seni yetkiliydi ama etkisiz elemandı\n\nŞimdi de etkisiz  ama yetkili eleman gibi davranan bir HİÇ olarak yazac… https://t.co/vWUbFxWY8j', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vWUbFxWY8j', 'expanded_url': 'https://twitter.com/i/web/status/1277498176774307841', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 840937471827443714, 'id_str': '840937471827443714', 'name': '🇹🇷EBRU ŞEHZADE🇹🇷', 'screen_name': 'SehzadeEbru', 'location': '#EvdeHayatVar', 'description': '"İyi hissedene kadar hiçbir şey hissetmek istemiyorum." @deli0412 👈𝓡𝓮𝓬𝓮𝓹𝓣𝓪𝔂𝔂𝓲𝓹𝓔𝓻𝓭𝓸𝓰𝓪𝓷', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 21011, 'friends_count': 17642, ' ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 15:04:29 +0000 2020', 'id': 1278343727929593856, 'id_str': '1278343727929593856', 'text': 'RT @ErolAslan__: Anlatmak istediğini değil de anlamak istediğini anlayanlar için söylenen her söz fazladır.\n(T. S. Eliot)\n\n#pazartesi', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [123, 133]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ErolAslan__', 'name': 'Erol Aslan', 'id': 2671447665, 'id_str': '2671447665', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 113609125, 'id_str': '113609125', 'name': 'derya özkök', 'screen_name': 'ddenizderya', 'location': '', 'description': 'Atatürk sen bizim her şeyimizsin...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 807, 'friends_count': 958, 'listed_count': 1, 'created_at': 'Fri Feb 12 11:40:26 +0000 2010', 'favourites_count': 13595, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 9120, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1275894225419321344/QI4tizcj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275894225419321344/QI4tizcj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113609125/1529987310', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Mar 23 09:21:01 +0000 2020', 'id': 1242018501914767362, 'id_str': '1242018501914767362', 'text': 'Anlatmak istediğini değil de anlamak istediğini anlayanlar için söylenen her söz fazladır.\n(T. S. Eliot)\n\n#pazartesi', 'truncated': False, 'entities': {'hashtags': [{'text': 'pazartesi', 'indices': [106, 116]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2671447665, 'id_str': '2671447665', 'name': 'Erol Aslan', 'screen_name': 'ErolAslan__', 'location': 'Izmir / Turkey', 'description': 'Yazar - Eğitmen, DEU | Hukuk', 'url': 'https://t.co/ERGsplTRSH', 'entities': {'url': {'urls': [{'url': 'https://t.co/ERGsplTRSH', 'expanded_url': 'http://www.erolaslan.com', 'display_url': 'erolaslan.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1027, 'friends_count': 84, 'listed_count': 41, 'created_at': 'Fri Jul 04 10:36:34 +0000 2014', 'favourites_count': 7696, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 5009, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_backgroun ...
# ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 11:20:48 +0000 2020', 'id': 1278287434866929665, 'id_str': '1278287434866929665', 'text': 'RT @POWERADE_532: #sokağacıkmayasağı  Bilemedim  şimdi Maskemi pardon kaskımı Takar çıkarım aman siz siz olun uymayın bana 🔞🚫⛔ #pazartesi h…', 'truncated': False, 'entities': {'hashtags': [{'text': 'sokağacıkmayasağı', 'indices': [18, 36]}, {'text': 'pazartesi', 'indices': [127, 137]}], 'symbols': [], 'user_mentions': [{'screen_name': 'POWERADE_532', 'name': '™️ TUNÇ', 'id': 1194647957204873216, 'id_str': '1194647957204873216', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 955010586185740288, 'id_str': '955010586185740288', 'name': 'ALÂ’', 'screen_name': 'O_1incim', 'location': '🇹🇷🤘🏻', 'description': 'Eyy! yâr’ı LeyL \U0001f90d_______’ iç’inde beni g’izle .. @Azra1inci', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1243, 'friends_count': 803, 'listed_count': 5, 'created_at': 'Sun Jan 21 09:34:01 +0000 2018', 'favourites_count': 83856, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 97259, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1276220601166958592/BuocNIZX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276220601166958592/BuocNIZX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/955010586185740288/1574503741', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Mar 16 10:31:47 +0000 2020', 'id': 1239499597061468160, 'id_str': '1239499597061468160', 'text': '#sokağacıkmayasağı  Bilemedim  şimdi Maskemi pardon kaskımı Takar çıkarım aman siz siz olun uymayın bana 🔞🚫⛔… https://t.co/cUKNx14EWm', 'truncated': True, 'entities': {'hashtags': [{'text': 'sokağacıkmayasağı', 'indices': [0, 18]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cUKNx14EWm', 'expanded_url': 'https://twitter.com/i/web/status/1239499597061468160', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [110, 133]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1194647957204873216, 'id_str': '1194647957204873216', 'name': '™️ TUNÇ', 'screen_name': 'POWERADE_532', 'location': 'İstanbul, Türkiye', 'description': "Twitter'a Bakıyorum 👉@powerade532", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1368, 'friends_count': 1306, 'listed_count': 4, 'created_at': 'Wed Nov 13 16:07:50 +0000 2019', 'favourites_count': 62703, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3355, 'lang': None, 'contributors_enabled': Fal ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 11:18:41 +0000 2020', 'id': 1278286900214870017, 'id_str': '1278286900214870017', 'text': "RT @OZLEMKILIC84: İşimi, niyetimi, yolumu ve yarınımı hayırlı kıl ALLAH'ım..\n\n#Pazartesi", 'truncated': False, 'entities': {'hashtags': [{'text': 'Pazartesi', 'indices': [78, 88]}], 'symbols': [], 'user_mentions': [{'screen_name': 'OZLEMKILIC84', 'name': 'ÖZLEM KILIÇ 🇹🇷', 'id': 564070489, 'id_str': '564070489', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1218495039481008128, 'id_str': '1218495039481008128', 'name': '🇹🇷🇹🇷🇹🇷 Akıncı Türk RT 🇹🇷🇹🇷🇹🇷', 'screen_name': 'AkncTrkRT3', 'location': 'İstanbul, Türkiye', 'description': '@Aknc14531071 RT hesabıdır . YERLİ VE MİLLİ 🇹🇷', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 298, 'friends_count': 15, 'listed_count': 0, 'created_at': 'Sat Jan 18 11:27:19 +0000 2020', 'favourites_count': 14548, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14650, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1218495873535090688/Gryl8ntm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218495873535090688/Gryl8ntm_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 06:53:47 +0000 2020', 'id': 1277495462149357568, 'id_str': '1277495462149357568', 'text': "İşimi, niyetimi, yolumu ve yarınımı hayırlı kıl ALLAH'ım..\n\n#Pazartesi", 'truncated': False, 'entities': {'hashtags': [{'text': 'Pazartesi', 'indices': [60, 70]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 564070489, 'id_str': '564070489', 'name': 'ÖZLEM KILIÇ 🇹🇷', 'screen_name': 'OZLEMKILIC84', 'location': 'Ankara, Türkiye', 'description': 'Karaköprü Belediyesi Sosyal yardım İşleri Müdürlüğü Akparti Karaköprü İlçe Kadın Kolları Teşkilat Başkanı 2015 -2018-Evli-Hitap Muhataba Biçilen Kıymettir.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 9233, 'friends_count': 7873, 'listed_count': 2, 'created_at': 'Thu Apr 26 21:49:47 +0000 2012', 'favourites_count': 9277, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 5229, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.tw ...
#  Status(_api=<tweepy.api.API object at 0x0000026AC4721C48>, _json={'created_at': 'Wed Jul 01 11:18:34 +0000 2020', 'id': 1278286874507907078, 'id_str': '1278286874507907078', 'text': 'RT @vatansever_058: Yeni Hafta kalbinde sevgi merhamet ve hoşgörü taşıyanlara sağlık mutluluk ve huzur getirsin Hayatta ne yaşanırsa yaşans…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'vatansever_058', 'name': 'ZHDE ÖZ 🇹🇷🇹🇷', 'id': 1070262594714435584, 'id_str': '1070262594714435584', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1218495039481008128, 'id_str': '1218495039481008128', 'name': '🇹🇷🇹🇷🇹🇷 Akıncı Türk RT 🇹🇷🇹🇷🇹🇷', 'screen_name': 'AkncTrkRT3', 'location': 'İstanbul, Türkiye', 'description': '@Aknc14531071 RT hesabıdır . YERLİ VE MİLLİ 🇹🇷', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 298, 'friends_count': 15, 'listed_count': 0, 'created_at': 'Sat Jan 18 11:27:19 +0000 2020', 'favourites_count': 14548, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14650, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1218495873535090688/Gryl8ntm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218495873535090688/Gryl8ntm_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 29 09:14:50 +0000 2020', 'id': 1277530957906694145, 'id_str': '1277530957906694145', 'text': 'Yeni Hafta kalbinde sevgi merhamet ve hoşgörü taşıyanlara sağlık mutluluk ve huzur getirsin Hayatta ne yaşanırsa ya… https://t.co/d6mP8cltxp', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/d6mP8cltxp', 'expanded_url': 'https://twitter.com/i/web/status/1277530957906694145', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1070262594714435584, 'id_str': '1070262594714435584', 'name': 'ZHDE ÖZ 🇹🇷🇹🇷', 'screen_name': 'vatansever_058', 'location': 'Bodrum, Türkiye', 'description': 'Bu vatana ihanet edenler ,bu ihanetin bedelini ödeyecektir .🇹🇷SENİNLEYİZ REİS🇹🇷 GRUPLARIN BAŞKANI 🇹🇷', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2406, 'friends_count': 2644, 'listed_count': 1, 'created_at': 'Wed Dec 05 10:24:21 +0000 2018', 'favourites_count': 6703, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1301, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_ba ...

# %%
for retweet in results:
    print(retweet.text)
# Out:
# RT @nurana571: Allah rahmet eylesin inşallah🤲 çok beğendim 👍👍📌 #anlatamam #kayahan #pazartesi #facebook_vs_twitter ⚖️https://t.co/6IN6zM099w
# RT @sademofficial: insan diyorum,
#
# zamanla değişmiyor,
#
# zorla değiştiriliyor________
#
#        G ü n a y d ı n   o   vakit
#
# #pazartesi htt…
# RT @mazidekalmiss: Selâmun Aleykűm Dostlar
# Yüreğiyle konuşan
# İnsanlar olsun hayatınızda
# Güzel bakışlarıyla
# Sıcak içten samimi
# Bi içimlik so…
# RT @yorukgiller: “Gece birbirlerini uyandırarak namaz kılan kadınlar ve erkekler, Allah’ı çok anan erkekler ve Allah’ı çok anan kadınlarara…
# RT @FundaBilir_: “Hiçbir yere varmayan yolları yürümenin müptelasıyım ben..”
# #GeceyeNotum #GeceyeBirNot
# #pazar #pazartesi 🌙🎶 https://t.co/p…
# RT @yorukgiller: "Çocuklarınızı üç haslet çerçevesinde terbiye ediniz:
# Peygamber sevgisi, Ehl-i Beyt muhabbeti ve Kur'an-ı Kerîm tilaveti."…
# RT @yorukgiller: "Allahı’ım! Kalbimin dağınıklığında sana sığınırım."
#
# Ebu’d-Derdâ
#
# #Pazartesi
# RT @sytcvs: #pazartesi Abdullah Gül fazla söze gerek var mı? "problemlerin çözümü için bir iki yere telefon açan Abdullah beyi şükranla yâd…
# RT @yorukgiller: Şairin dediği gibi;
#
# “Ehline denk gelmeyen her şey ziyan olur.Can da, inci mercan da...”
#
# Ehlinize denk düşesiniz.
#
# #Pazar…
# RT @Osman12443386: Ve yapılan hizmete dayanamayan
# Alkışlamamak tan çılgına dönen balıkların, Küçükçekmece gölünde toplu balık ölümleri gerç…
# RT @_SelimYvzhn: Hulâsa-i kelâm ve kelamların en güzeli der ki:
# "Allah'ın Rahmetinden Ümidinizi Kesmeyin.."
# ▪Zümer|53
# #hayırlısabahlar 🖤☕️…
# RT @tameristan5: Bazı haftalar yorucu ve streslidir
#      gerginliğinizi atmak için
# Bütün sıkıntılarınızı
#     elinizin tersiyle itin..
#
# Gün…
# RT @SecerVahap: #Günaydın
#
# Bereketin, renklerin, sağlık ve mutluluğun bir olduğu güzel bir hafta olsun. #İyiHaftalar #Pazartesi https://t.c…
# RT @POWERADE_532: #sokağacıkmayasağı  Bilemedim  şimdi Maskemi pardon kaskımı Takar çıkarım aman siz siz olun uymayın bana 🔞🚫⛔ #pazartesi h…
# RT @ffaattmmaagul: 12 yaşında bir evladım ile yalnız yaşıyoruz. Eşimden ayrıyım. İş bulana kadar geçimi lif satarak sağlamak için lif satıy…
# RT @ffaattmmaagul: 12 yaşında bir evladım ile yalnız yaşıyoruz. Eşimden ayrıyım. İş bulana kadar geçimi lif satarak sağlamak için lif satıy…
# RT @mcanpolatnet: Yeni haftaya, yeni güne Bismillah.
# Dualarımızın kabul olduğu, ferah ve sağlıklı bir hafta olması dileğiyle.
#
# Hayırlı sab…
# RT @FundaBilir_: “Hiçbir yere varmayan yolları yürümenin müptelasıyım ben..”
# #GeceyeNotum #GeceyeBirNot
# #pazar #pazartesi 🌙🎶 https://t.co/p…
# RT @Hival90: Son günlerde ülkenin her bölgesinde depremler oluyor,İnşaAllah daha büyük bir depremin habercisi değildir,Rabbim bütün afetler…
# RT @AsElektirik: Fatih Erbakan : İstanbul Sözleşmesini Yırtıp Atacağız. #dolar #pride #PRIDE2020 SONUNDA KALKTI #KatilAKP Enes Kanter #Müge…
# RT @ponciksebastian: Çalışmak güzel şey,
# Bir bardak çay,
# Bolca umut,
# Birazda yaşam sevinci
# ✌️✌️✌️
# #çalışmak #umut #pazartesi https://t.c…
# RT @POWERADE_532: #sokağacıkmayasağı  Bilemedim  şimdi Maskemi pardon kaskımı Takar çıkarım aman siz siz olun uymayın bana 🔞🚫⛔ #pazartesi h…
# RT @OZLEMKILIC84: İşimi, niyetimi, yolumu ve yarınımı hayırlı kıl ALLAH'ım..
#
# #Pazartesi
# RT @vatansever_058: Yeni Hafta kalbinde sevgi merhamet ve hoşgörü taşıyanlara sağlık mutluluk ve huzur getirsin Hayatta ne yaşanırsa yaşans…

# %%
#dataframe cevirmek

# %%
def tweets_df(results):
    id_list = [tweet.id for tweet  in results]
    import pandas as pd
    data_set = pd.DataFrame(id_list, columns = ["id"])
    
    data_set["text"] = [tweet.text for tweet in results]
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in results]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in results]
    
    return data_set

# %%
data = tweets_df(results)

# %%
data["text"]

# %%
data.to_csv("data_twitter.csv")

# %% [markdown]
# # Profil Analizi

# %%
#temel bilgiler

# %%
mvk = api.get_user("mvahitkeskin")

# %%
mvk.name

# %%
mvk.id

# %%
mvk.url

# %%
mvk.verified

# %%
mvk.screen_name

# %%
mvk.location

# %%
mvk.statuses_count

# %%
mvk.followers_count

# %%
mvk.favourites_count

# %%
mvk.friends_count

# %%
tweets = api.user_timeline(id = "mvahitkeskin")

# %%
for i in tweets:
    print(i.text)

# %%
def timeline_df(tweets):
    idler = [tweet.id for tweet  in tweets]
    import pandas as pd
    df = pd.DataFrame(idler, columns = ["id"])
    
    df["created_at"] = [tweet.created_at for tweet in tweets]
    df["text"] = [tweet.text for tweet in tweets]
    df["favorite_count"] = [tweet.favorite_count for tweet in tweets]
    df["retweet_count"] = [tweet.retweet_count for tweet in tweets]
    df["source"] = [tweet.source for kisi in tweets]
    
    return df

# %%
timeline_df(tweets)

# %%
def  timeline_df(tweets):
    import pandas as pd
    df = pd.DataFrame()
    df['id'] = list(map(lambda tweet: tweet.id, tweets))
    df['created_at'] = list(map(lambda tweet: tweet.created_at, tweets))
    df['text'] = list(map(lambda tweet: tweet.text, tweets))
    df['favorite_count'] = list(map(lambda tweet: tweet.favorite_count, tweets))
    df['retweet_count'] = list(map(lambda tweet: tweet.retweet_count, tweets))
    df['source'] = list(map(lambda tweet: tweet.source, tweets))
    return df

# %%
tweets = api.user_timeline(id = "fatihportakal", count = 200)
df = timeline_df(tweets)

# %%
# ?api.user_timeline

# %%
# ?tweets

# %%
df.shape

# %%
df.head()

# %%
#profil enleri

# %%
df.sort_values("favorite_count", ascending = False).head()

# %%
df.sort_values("retweet_count", ascending = False)[["text","retweet_count"]].iloc[0:3]

# %%
df.sort_values("favorite_count", ascending = False)[["text","favorite_count"]].iloc[0:3]

# %% [markdown]
# ## Retweet & Favori Sayılarının Dağılımlarının Çıkarılması

# %%
df.head()

# %%
# %config InlineBackend.figure_format = 'retina'
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df.favorite_count, kde = False, color = "blue");

# %%
sns.distplot(df.retweet_count, color = "blue");
plt.xlim(-100, 5000)

# %% [markdown]
# ## Tweet-Saat Dağılımı

# %%
df.head()

# %%
df["tweet_saati"] = df["created_at"].apply(lambda x: x.strftime("%H"))

# %%
df.head()

# %%
import pandas as pd
df["tweet_saati"] = pd.to_numeric(df["tweet_saati"])
df.info()

# %%
sns.distplot(df["tweet_saati"], kde = False, color ="blue");

# %%
df["gunler"] = df["created_at"].dt.weekday_name

# %%
df.head()

# %%
df.groupby("gunler").count()["id"]

# %%
gun_freq = df.groupby("gunler").count()["id"]

# %%
gun_freq.plot.bar(x = "gunler", y = "id")

# %% [markdown]
# ## Tweet Atma Kaynaklarının Betimlenmesi

# %%
kaynak_freq = df.groupby("source").count()["id"]

# %%
kaynak_freq.plot.bar(x = "source", y = "id")

# %%
df.groupby("source").count()["id"]

# %%
df.groupby(["source","tweet_saati","gunler"])[["tweet_saati"]].count()

# %% [markdown]
# ## Takipçi ve Arkadaşların Analizi

# %%
user = api.get_user(id = "fatihportakal")

# %%
for friend in user.friends():
    print(friend.screen_name)

# %%
friends = user.friends()
followers = user.followers()

# %%
def followers_df(takipci):
    import pandas as pd
    idler = [kisi.id for kisi  in takipci]
    df = pd.DataFrame(idler, columns = ["id"])
    
    df["created_at"] = [kisi.created_at for kisi in takipci]
    df["screen_name"] = [kisi.screen_name for kisi in takipci]
    df["location"] = [kisi.location for kisi in takipci]
    df["followers_count"] = [kisi.followers_count for kisi in takipci]
    df["statuses_count"] = [kisi.statuses_count for kisi in takipci]
    df["friends_count"] = [kisi.friends_count for kisi in takipci]
    df["favourites_count"] = [kisi.favourites_count for kisi in takipci]
    
    return df

# %%
df = followers_df(followers)

# %%
df.head()

# %% [markdown]
# ## Takipçi Segmentasyonu

# %%
df.head()

# %%
df.index = df["screen_name"]

# %%
df.head()

# %%
s_data = df[["followers_count", "statuses_count"]]

# %%
s_data.info()

# %%
s_data

# %%
s_data["followers_count"] = s_data["followers_count"] + 0.01
s_data["statuses_count"] = s_data["statuses_count"] + 0.01

# %%
s_data

# %%
6.01 * 1.01

# %%
4.01 * 39.01

# %%
3 * 0.01

# %%
s_data = s_data.apply(lambda x: (x-min(x))/(max(x)-min(x)))

# %%
s_data["followers_count"] = s_data["followers_count"] + 0.01
s_data["statuses_count"] = s_data["statuses_count"] + 0.01

# %%
s_data.head()

# %%
skor = s_data["followers_count"] * s_data["statuses_count"]

# %%
skor

# %%
skor.sort_values(ascending = False)

# %%
skor[skor > skor.median() + skor.std()/len(skor)].sort_values(ascending = False)

# %%
skor.std()

# %%
skor.median()

# %%
s_data["skor"] = skor

# %%
s_data

# %%
import numpy as np
s_data["segment"] = np.where(s_data["skor"] >= skor.median() + 
                             skor.std()/len(skor), "A","B")

# %%
s_data

# %% [markdown]
# # Hashtag Analizi

# %%
api.trends_available()

# %%
def ulke_kodlari():
    places = api.trends_available()
    all_woeids = {place['name'].lower(): place['woeid'] for place in places}
    return all_woeids

# %%
ulke_kodlari()

# %%
def ulke_woeid(ulke_adi):
    ulke_adi = ulke_adi.lower()
    trends = api.trends_available()
    all_woeids = ulke_kodlari()
    return all_woeids[ulke_adi]

# %%
23424969

# %%
ulke_woeid("turkey")

# %%
trendler = api.trends_place(id = 23424969)

# %%
import json
print(json.dumps(trendler, indent = 4))

# %%
turkiye = api.trends_place(id = 23424969)
trendler = turkiye[0]["trends"]

# %%
for i in trendler:
    print(i["name"])

# %% [markdown]
# ## Hashtag'den Veri Çekmek

# %%
tweetler = api.search(q = "#pazartesi", 
                      lang = "tr", 
                      result_type = "recent", 
                     count = 1000)

# %%
def hashtag_df(tweetler):
    import pandas as pd
    id_list = [tweet.id for tweet  in tweetler]
    df = pd.DataFrame(id_list, columns = ["id"])
    
    df["text"] = [tweet.text for tweet in tweetler]
    df["created_at"] = [tweet.created_at for tweet in tweetler]
    df["retweeted"] = [tweet.retweeted for tweet in tweetler]
    df["retweet_count"] = [tweet.retweet_count for tweet in tweetler]
    df["user_screen_name"] = [tweet.author.screen_name for tweet in tweetler]
    df["user_followers_count"] = [tweet.author.followers_count for tweet in tweetler]
    df["user_location"] = [tweet.author.location for tweet in tweetler]
    df["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweetler]
    
    return df

# %%
df = hashtag_df(tweetler)

# %%
df.shape

# %%
df.head()

# %% [markdown]
# ## Hashtag Betimlemek

# %%
#essiz katılımcı

# %%
df.head()

# %%
df["user_screen_name"].unique().size

# %%
df.groupby("user_screen_name")["id"].count().sum()

# %%
#en cok katkı sağlayanlar

# %%
df.groupby("user_screen_name").count()["id"].sort_values(ascending = False)[0:5]

# %%
#ozgun katkı

# %%
df.head()

# %%
df["text"].str.startswith("RT").head(10)

# %%
df[~df["text"].str.startswith("RT")].count()["id"] / len(df)

# %%
df[~df["text"].str.startswith("RT")].count()["id"] / df[df["text"].str.startswith("RT")].count()["id"]

# %%
## en cok fav-retweet

# %%
df.sort_values("retweet_count", ascending = False).head()

# %% [markdown]
# ## Tweet-Saat Dağılımı

# %%
# ?api.search

# %%
tweetler = api.search(q = "#datascience", lang = "en", count = 5000)

# %%
def hashtag_df(tweetler):
    import pandas as pd
    id_list = [tweet.id for tweet  in tweetler]
    df = pd.DataFrame(id_list, columns = ["id"])
    
    df["text"] = [tweet.text for tweet in tweetler]
    df["created_at"] = [tweet.created_at for tweet in tweetler]
    df["retweeted"] = [tweet.retweeted for tweet in tweetler]
    df["retweet_count"] = [tweet.retweet_count for tweet in tweetler]
    df["source"] = [tweet.source for tweet in tweetler]
    df["user_screen_name"] = [tweet.author.screen_name for tweet in tweetler]
    df["user_followers_count"] = [tweet.author.followers_count for tweet in tweetler]
    df["user_location"] = [tweet.author.location for tweet in tweetler]
    df["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweetler]
    
    return df

# %%
df = hashtag_df(tweetler)

# %%
df.shape

# %%
df["tweet_saati"] = df["created_at"].apply(lambda x: x.strftime("%H"))

# %%
df.head()

# %%
import pandas as pd
df["tweet_saati"] = pd.to_numeric(df["tweet_saati"])
df.info()

# %%
sns.distplot(df["tweet_saati"], kde = False, color ="blue");

# %%
df["gunler"] = df["created_at"].dt.weekday_name

# %%
df.head()

# %%
df.groupby("gunler").count()["id"]

# %%
gun_freq = df.groupby("gunler").count()["id"]

# %%
gun_freq.plot.bar(x = "gunler", y = "id")

# %% [markdown]
# ## Tweet Atma Kaynaklarının Betimlenmesi

# %%
kaynak_freq = df.groupby("source").count()["id"]

# %%
kaynak_freq.plot.bar(x = "source", y = "id")

# %%
df.groupby("source").count()["id"]

# %% [markdown]
# # Twitter Text Mining

# %%
df = hashtag_df(tweetler)

#buyuk-kucuk donusumu
df['text'] = df['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#noktalama işaretleri
df['text'] = df['text'].str.replace('[^\w\s]','')

#sayılar
df['text'] = df['text'].str.replace('\d','')

#stopwords
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('english')
df['text'] = df['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

#lemmi
from textblob import Word
#nltk.download('wordnet')
df['text'] = df['text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()])) 

#noktalama işaretleri
df['text'] = df['text'].str.replace('rt','')

# %%
df["text"]

# %%
freq_df = df["text"].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis =0).reset_index()

# %%
freq_df.columns = ["kelimeler","frekanslar"]

# %%
freq_df.shape

# %%
freq_df[freq_df.frekanslar > freq_df.frekanslar.mean() + 
        freq_df.frekanslar.std()]

# %%
a = freq_df[freq_df.frekanslar > freq_df.frekanslar.mean() + 
        freq_df.frekanslar.std()]

# %%
a.plot.bar(x = "kelimeler",y = "frekanslar");

# %% [markdown]
# ## Word cloud

# %%
#!pip install wordcloud

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
text = " ".join(i for i in df.text)

# %%
text

# %%
wordcloud = WordCloud(background_color = "white").generate(text)
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
vbo_mask = np.array(Image.open("VBO.jpg"))

# %%
wc = WordCloud(background_color = "white", 
               max_words = 1000, 
               mask = vbo_mask,
              contour_width = 3, 
              contour_color = "firebrick")

wc.generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation = "bilinear")
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# # Twitter Sentiment Analizi

# %%
df

# %%
from textblob import TextBlob

# %%
def sentiment_skorla(df):

    text = df["text"]

    for i in range(0,len(text)):
        textB = TextBlob(text[i])
        sentiment_skoru = textB.sentiment.polarity
        df.set_value(i, 'sentiment_skoru', sentiment_skoru)
        
        if sentiment_skoru <0.00:
            duygu_sinifi = 'Negatif'
            df.set_value(i, 'duygu_sinifi', duygu_sinifi )

        elif sentiment_skoru >0.00:
            duygu_sinifi = 'Pozitif'
            df.set_value(i, 'duygu_sinifi', duygu_sinifi )

        else:
            duygu_sinifi = 'Notr'
            df.set_value(i, 'duygu_sinifi', duygu_sinifi )
            
    return df

# %%
df.head()

# %%
sentiment_skorla(df)

# %%
df.groupby("duygu_sinifi").count()["id"]

# %%
duygu_freq = df.groupby("duygu_sinifi").count()["id"]

# %%
duygu_freq.plot.bar(x = "duygu_sinifi",y = "id");

# %%
tweetler = api.search(q = "#apple", lang = "en")

# %%
df = hashtag_df(tweetler)

# %%
#buyuk-kucuk donusumu
df['text'] = df['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#noktalama işaretleri
df['text'] = df['text'].str.replace('[^\w\s]','')

#sayılar
df['text'] = df['text'].str.replace('\d','')

#stopwords
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('english')
df['text'] = df['text'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

#lemmi
from textblob import Word
#nltk.download('wordnet')
df['text'] = df['text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()])) 

#noktalama işaretleri
df['text'] = df['text'].str.replace('rt','')

# %%
sentiment_skorla(df)

# %%
duygu_freq = df.groupby("duygu_sinifi").count()["id"]

# %%
duygu_freq.plot.bar(x = "duygu_sinifi",y = "id");
